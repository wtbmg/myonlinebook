# %% [markdown]
# # Question 2
#
# Based on existing data, on average, have movies become more or less revenue generating over time based on inflation-adjusted gross? Which directors are featured in top 10 G-rated inflation-adjusted gross movies in the last half century (1972 - 2022)?
#
# **Methods and Results**
#
# To answer Q2:
# use dateime to year to group gross by year; used data frames disney-director.csv, and disney_movie_total_gross.csv.

# %%
import pandas as pd
import altair as alt

# %%
# import data, datetime as datetime 
dm_total_gross = pd.read_csv('data/disney_movies_total_gross.csv', parse_dates = ['release_date'])

dm_total_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 579 entries, 0 to 578
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   movie_title               579 non-null    object
#  1   release_date              579 non-null    datetime64[ns]
#  2   genre                     562 non-null    object
#  3   MPAA_rating               523 non-null    object
#  4   total_gross               579 non-null    object
#  5   inflation_adjusted_gross  579 non-null    object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 27.3+ KB

# %% [markdown]
# In data wrangling, we noticed below that some columns include special characters and/or may not be of the type we need for mathematical calculations. In lieu of dealing with them column by column, we could write a function to do the stripping and type re-assignment for us.

# %% [markdown]
# ```
# def replace_char(df, col, special_character):
#     import pandas as pd
#     df_after=df.assign(col=df['col'].str.strip('special_character'))
#
#     return df_after
# ```

# %% [markdown]
# ```
# def coltype_chg(df, col, col_type):
#     import pandas as pd
#     df_after=df.assign(col=df['col'].astype('col_type'))
#
#     return df_after
# ```

# %%
# strip the $ sign from gross, remove ',' & set appropriate datatypes for columns so calculation can be done property 
dm_total_gross = dm_total_gross.assign(total_gross = dm_total_gross['total_gross'].str.strip('$'))
dm_total_gross = dm_total_gross.assign(inflation_adjusted_gross = dm_total_gross['inflation_adjusted_gross'].str.strip('$'))
dm_total_gross = dm_total_gross.assign(total_gross = dm_total_gross['total_gross'].str.replace(',', ''))
dm_total_gross = dm_total_gross.assign(inflation_adjusted_gross = dm_total_gross['inflation_adjusted_gross'].str.replace(',', ''))

dm_total_gross = dm_total_gross.assign(total_gross = dm_total_gross['total_gross'].astype('float'))
dm_total_gross = dm_total_gross.assign(inflation_adjusted_gross = dm_total_gross['inflation_adjusted_gross'].astype('float'))

# %%
dm_total_gross.head()
# Out:
#                        movie_title release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross
# 0  184925485.0              5.228953e+09
# 1   84300000.0              2.188229e+09
# 2   83320000.0              2.187091e+09
# 3   65000000.0              1.078511e+09
# 4   85000000.0              9.206087e+08

# %%
# since we are comparing by year, need to assign a new column with the year of the movie release; set the display for float format so the data is more readable by human(me)
dm_total_gross = dm_total_gross.assign(release_year = dm_total_gross['release_date'].dt.year)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
dm_total_gross.head()
# Out:
#                        movie_title release_date      genre MPAA_rating  \
# 0  Snow White and the Seven Dwarfs   1937-12-21    Musical           G
# 1                        Pinocchio   1940-02-09  Adventure           G
# 2                         Fantasia   1940-11-13    Musical           G
# 3                Song of the South   1946-11-12  Adventure           G
# 4                       Cinderella   1950-02-15      Drama           G
#
#    total_gross  inflation_adjusted_gross  release_year
# 0 184925485.00             5228953251.00          1937
# 1  84300000.00             2188229052.00          1940
# 2  83320000.00             2187090808.00          1940
# 3  65000000.00             1078510579.00          1946
# 4  85000000.00              920608730.00          1950

# %%
year_mean = dm_total_gross.groupby('release_year').mean().reset_index()
year_count = pd.DataFrame(dm_total_gross['release_year'].value_counts()).reset_index().rename(columns={'release_year':'movie_count', 'index':'release_year'})

merged = year_mean.merge(year_count,on = 'release_year')
merged.head()
# Out:
#    release_year  total_gross  inflation_adjusted_gross  movie_count
# 0          1937 184925485.00             5228953251.00            1
# 1          1940  83810000.00             2187659930.00            2
# 2          1946  65000000.00             1078510579.00            1
# 3          1950  85000000.00              920608730.00            1
# 4          1954  28200000.00              528279994.00            1

# %% [markdown]
# Below is a plot demostraing the yearly movie gross mean

# %%
# plot the yearly movie gross mean
plot_ym = alt.Chart(merged).mark_line().encode(
    x = 'release_year',
    y = 'inflation_adjusted_gross')
plot_ym
# Out:
# alt.Chart(...)

# %% [markdown]
# Below is a plot demonstrating the yearly movie produced sum

# %%
plot_mc = plot_ym = alt.Chart(merged).mark_bar().encode(
    x = 'release_year',
    y = 'movie_count')
plot_mc
# Out:
# alt.Chart(...)

# %% [markdown]
# Below moving on to address director questions by merging dataframes, as well as to filter and loc.

# %%
#import dataframes
directors = pd.read_csv('data/disney-director.csv')

# %%
directors.info()
directors.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      56 non-null     object
#  1   director  56 non-null     object
# dtypes: object(2)
# memory usage: 1.0+ KB
#                               name        director
# 0  Snow White and the Seven Dwarfs      David Hand
# 1                        Pinocchio  Ben Sharpsteen
# 2                         Fantasia    full credits
# 3                            Dumbo  Ben Sharpsteen
# 4                            Bambi      David Hand

# %% [markdown]
# ```{figure} snowwhite.jpeg
# ---
# height: 450px
# name: snowwhite
# ---
# Based on this dataset, SnowWhite ranks top by inflation adjusted revenue.
# ```
#
# Source of image: https://movies.disney.com/snow-white-and-the-seven-dwarfs

# %%
# I filtered for the years I cared about
dm_loc = dm_total_gross[dm_total_gross['release_year']>= 1972]
dm_loc.head()
# Out:
#                                 movie_title release_date      genre  \
# 18                  The Apple Dumpling Gang   1975-07-01     Comedy
# 19                            Freaky Friday   1977-01-21     Comedy
# 20   The Many Adventures of Winnie the Pooh   1977-03-11        NaN
# 21                             The Rescuers   1977-06-22  Adventure
# 22               Herbie Goes to Monte Carlo   1977-06-24        NaN
# ..                                      ...          ...        ...
# 574                The Light Between Oceans   2016-09-02      Drama
# 575                          Queen of Katwe   2016-09-23      Drama
# 576                          Doctor Strange   2016-11-04  Adventure
# 577                                   Moana   2016-11-23  Adventure
# 578            Rogue One: A Star Wars Story   2016-12-16  Adventure
#
#     MPAA_rating  total_gross  inflation_adjusted_gross  release_year
# 18          NaN  31916500.00              131246872.00          1975
# 19          NaN  25942000.00               98067733.00          1977
# 20          NaN         0.00                      0.00          1977
# 21          NaN  48775599.00              159743914.00          1977
# 22          NaN  28000000.00              105847527.00          1977
# ..          ...          ...                       ...           ...
# 574       PG-13  12545979.00               12545979.00          2016
# 575          PG   8874389.00                8874389.00          2016
# 576       PG-13 232532923.00              232532923.00          2016
# 577          PG 246082029.00              246082029.00          2016
# 578       PG-13 529483936.00              529483936.00          2016
#
# [561 rows x 7 columns]

# %%
merged = dm_loc.merge(directors, left_on = 'movie_title', right_on = 'name')
merged.head()
# Out:
#                                movie_title release_date      genre  \
# 0   The Many Adventures of Winnie the Pooh   1977-03-11        NaN
# 1                             The Rescuers   1977-06-22  Adventure
# 2                    The Fox and the Hound   1981-07-10     Comedy
# 3                       The Black Cauldron   1985-07-24  Adventure
# 4                The Great Mouse Detective   1986-07-02  Adventure
# 5                         Oliver & Company   1988-11-18  Adventure
# 6                       The Little Mermaid   1989-11-15  Adventure
# 7                  The Rescuers Down Under   1990-11-16  Adventure
# 8                     Beauty and the Beast   1991-11-13    Musical
# 9                                  Aladdin   1992-11-11     Comedy
# 10                           The Lion King   1994-06-15  Adventure
# 11                         The Jungle Book   1994-12-25  Adventure
# 12                         The Jungle Book   2016-04-15  Adventure
# 13                              Pocahontas   1995-06-10  Adventure
# 14             The Hunchback of Notre Dame   1996-06-21  Adventure
# 15                          101 Dalmatians   1996-11-27     Comedy
# 16                                Hercules   1997-06-13  Adventure
# 17                                   Mulan   1998-06-19  Adventure
# 18                                  Tarzan   1999-06-16  Adventure
# 19                                Dinosaur   2000-05-19  Adventure
# 20                The Emperor's New Groove   2000-12-15  Adventure
# 21               Atlantis: The Lost Empire   2001-06-08  Adventure
# 22                           Lilo & Stitch   2002-06-21  Adventure
# 23                         Treasure Planet   2002-11-27  Adventure
# 24                            Brother Bear   2003-10-24  Adventure
# 25                       Home on the Range   2004-04-02     Comedy
# 26                          Chicken Little   2005-11-04  Adventure
# 27                      Meet the Robinsons   2007-03-30  Adventure
# 28                                    Bolt   2008-11-21     Comedy
# 29               The Princess and the Frog   2009-11-25  Adventure
# 30                     Alice in Wonderland   2010-03-05  Adventure
# 31                                 Tangled   2010-11-24  Adventure
# 32                         Winnie the Pooh   2011-07-15  Adventure
# 33                          Wreck-It Ralph   2012-11-02  Adventure
# 34                                  Frozen   2013-11-22  Adventure
# 35                              Big Hero 6   2014-11-07  Adventure
# 36                              Cinderella   2015-03-13      Drama
# 37                                Zootopia   2016-03-04  Adventure
# 38                                   Moana   2016-11-23  Adventure
#
#    MPAA_rating  total_gross  inflation_adjusted_gross  release_year  \
# 0          NaN         0.00                      0.00          1977
# 1          NaN  48775599.00              159743914.00          1977
# 2          NaN  43899231.00              133118889.00          1981
# 3          NaN  21288692.00               50553142.00          1985
# 4          NaN  23605534.00               53637367.00          1986
# 5            G  49576671.00              102254492.00          1988
# 6            G 111543479.00              223726012.00          1989
# 7            G  27931461.00               55796728.00          1990
# 8            G 218951625.00              363017667.00          1991
# import the custom script
from custom_filter import custom_filter 

# run it on the data
Top10_dir = custom_filter('MPAA_rating','G','inflation_adjusted_gross',merged,10)

Top10_dir
# Out:
#                     movie_title release_date      genre MPAA_rating  \
# 10                The Lion King   1994-06-15  Adventure           G
# 9                       Aladdin   1992-11-11     Comedy           G
# 8          Beauty and the Beast   1991-11-13    Musical           G
# 18                       Tarzan   1999-06-16  Adventure           G
# 13                   Pocahontas   1995-06-10  Adventure           G
# 15               101 Dalmatians   1996-11-27     Comedy           G
# 6            The Little Mermaid   1989-11-15  Adventure           G
# 17                        Mulan   1998-06-19  Adventure           G
# 14  The Hunchback of Notre Dame   1996-06-21  Adventure           G
# 16                     Hercules   1997-06-13  Adventure           G
#
#     total_gross  inflation_adjusted_gross  release_year  \
# 10 422780140.00              761640898.00          1994
# 9  217350219.00              441969178.00          1992
# 8  218951625.00              363017667.00          1991
# 18 171091819.00              283900254.00          1999
# 13 141579773.00              274370957.00          1995
# 15 136189294.00              258728898.00          1996
# 6  111543479.00              223726012.00          1989
# 17 120620254.00              216807832.00          1998
# 14 100138851.00              190988799.00          1996
# 16  99112101.00              182029412.00          1997
#
#                            name             director
# 10                The Lion King         Roger Allers
# 9                       Aladdin         Ron Clements
# 8          Beauty and the Beast       Gary Trousdale
# 18                       Tarzan           Chris Buck
# 13                   Pocahontas         Mike Gabriel
# 15               101 Dalmatians  Wolfgang Reitherman
# 6            The Little Mermaid         Ron Clements
# 17                        Mulan           Barry Cook
# 14  The Hunchback of Notre Dame       Gary Trousdale
# 16                     Hercules         Ron Clements

# %%
#formatting

# !black custom_filter.py
# !black notebooks.ipynb
# Out:
# All done! ✨ 🍰 ✨
# 1 file left unchanged.
# Usage: black [OPTIONS] SRC ...
# Try 'black -h' for help.
#
# Error: Invalid value for 'SRC ...': Path 'notebooks.ipynb' does not exist.

# %% [markdown]
# ```{figure} lion-king.webp
# ---
# height: 450px
# name: lionking
# ---
# Lion King is another major success of Disney
# ```
#
# Source of image: https://www.nytimes.com/2019/07/18/movies/disney-lion-king.html

# %% [markdown]
# :::{seealso}
# Now, since there really isn't any math equations this project needed, but the Jupyter Book demands two math equations... I thought I'd insert two simple equations brought up in this article [The Mathematics of f/stop Aperture Numbers](http://pleasemakeanote.blogspot.com/2010/10/mathematics-of-fstop-aperture-numbers.html), below are the equations re-produced based on this source.
# :::

# %% [markdown]
# Code as below:
#
# ```{math}
# :label: stop_cal
#   S = \frac {f}{D}
# ```
#
# ```{math}
# :label: diameter_cal
#   D = \frac {f}{D}
# ```
#
# where
# S = stop number;
# f = Focal Length;
# D = Aperture Diameter.
#
# To quote an example from the source, "a lens set at a focal length of 70mm and a stop number of 5.6 has an aperture diameter of 12.5mm."

# %% [markdown]
# Additionally, "for an aperture to let in twice as much light, its diameter must increase by approximately 41%." As shown in this equation below.

# %% [markdown]
# ```{math}
# :label: diameter_incr
#   {D_0} = \sqrt{2}{D_1} \approx {D_1} + 0.414{D_1}
# ```
